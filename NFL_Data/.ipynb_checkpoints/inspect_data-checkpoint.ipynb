# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("pbp-2019.csv")
data.head()
# Out:
#        GameId    GameDate  Quarter  Minute  Second OffenseTeam DefenseTeam  \
# 0  2019112400  2019-11-24        2       0      44          TB         ATL
# 1  2019112400  2019-11-24        2       7      55          TB         ATL
# 2  2019111100  2019-11-11        1       2       3          SF         SEA
# 3  2019112100  2019-11-21        4       0       5         HOU         IND
# 4  2019112100  2019-11-21        4       0      50         HOU         IND
#
#    Down  ToGo  YardLine  ...  IsTwoPointConversion  \
# 0     2     1        99  ...                     0
# 1     0     0        85  ...                     0
# 2     0     0        85  ...                     0
# 3     4     3        65  ...                     0
# 4     3     3        65  ...                     0
#
#    IsTwoPointConversionSuccessful  RushDirection  YardLineFixed  \
# 0                               0            NaN              1
# 1                               0            NaN             15
# ...

# %%
four_data = data.loc[data['Down'] == 4]

# %%
four_data.head()
# Out:
#         GameId    GameDate  Quarter  Minute  Second OffenseTeam DefenseTeam  \
# 3   2019112100  2019-11-21        4       0       5         HOU         IND
# 37  2019110700  2019-11-07        2       2       0         OAK         LAC
# 52  2019111704  2019-11-17        4       0      47         MIA         BUF
# 57  2019111701  2019-11-17        1      11      39         ATL         CAR
# 59  2019111400  2019-11-14        4      13      29         PIT         CLE
#
#     Down  ToGo  YardLine  ...  IsTwoPointConversion  \
# 3      4     3        65  ...                     0
# 37     4     1        60  ...                     0
# 52     4     4        69  ...                     0
# 57     4     4        80  ...                     0
# 59     4     1        68  ...                     0
#
#     IsTwoPointConversionSuccessful  RushDirection  YardLineFixed  \
# 3                                0            NaN             35
# ...

# %%
four_data.describe()
# Out:
#              GameId      Quarter       Minute       Second    Down  \
# count  2.673000e+03  2673.000000  2673.000000  2673.000000  2673.0
# mean   2.019101e+09     2.601945     6.264123    29.057239     4.0
# std    8.062873e+03     1.129104     4.380889    17.627468     0.0
# min    2.019090e+09     1.000000     0.000000     0.000000     4.0
# 25%    2.019092e+09     2.000000     2.000000    14.000000     4.0
# 50%    2.019101e+09     3.000000     6.000000    29.000000     4.0
# 75%    2.019111e+09     4.000000    10.000000    44.000000     4.0
# max    2.019112e+09     5.000000    15.000000    59.000000     4.0
#
#               ToGo     YardLine  Unnamed: 10  SeriesFirstDown  Unnamed: 12  \
# count  2673.000000  2673.000000          0.0      2673.000000          0.0
# mean      8.265993    49.986532          NaN         0.068462          NaN
# std       5.943216    24.958975          NaN         0.252585          NaN
# ...

# %%
four_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-7f798f9d7246> in <module>
# ----> 1 four_data()
#
# TypeError: 'DataFrame' object is not callable

# %%
four_data
# Out:
#            GameId    GameDate  Quarter  Minute  Second OffenseTeam  \
# 3      2019112100  2019-11-21        4       0       5         HOU
# 37     2019110700  2019-11-07        2       2       0         OAK
# 52     2019111704  2019-11-17        4       0      47         MIA
# 57     2019111701  2019-11-17        1      11      39         ATL
# 59     2019111400  2019-11-14        4      13      29         PIT
# ...           ...         ...      ...     ...     ...         ...
# 31311  2019090500  2019-09-05        4       1      45          GB
# 31320  2019090500  2019-09-05        4       5      20          GB
# 31341  2019090801  2019-09-08        3       6      13         TEN
# 31343  2019090801  2019-09-08        3       8      29         CLE
# 31351  2019090800  2019-09-08        2       1       7          LA
#
#       DefenseTeam  Down  ToGo  YardLine  ...  IsTwoPointConversion  \
# 3             IND     4     3        65  ...                     0
# ...

# %%
column_list = []
for column in four_data.columns:
    column_list.append(column)
    
column_list
# Out:
# ['GameId',
#  'GameDate',
#  'Quarter',
#  'Minute',
#  'Second',
#  'OffenseTeam',
#  'DefenseTeam',
#  'Down',
#  'ToGo',
#  'YardLine',
#  'Unnamed: 10',
#  'SeriesFirstDown',
#  'Unnamed: 12',
#  'NextScore',
#  'Description',
#  'TeamWin',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'SeasonYear',
#  'Yards',
#  'Formation',
#  'PlayType',
#  'IsRush',
#  'IsPass',
#  'IsIncomplete',
#  'IsTouchdown',
#  'PassType',
#  'IsSack',
#  'IsChallenge',
#  'IsChallengeReversed',
#  'Challenger',
#  'IsMeasurement',
#  'IsInterception',
#  'IsFumble',
#  'IsPenalty',
#  'IsTwoPointConversion',
#  'IsTwoPointConversionSuccessful',
#  'RushDirection',
#  'YardLineFixed',
#  'YardLineDirection',
#  'IsPenaltyAccepted',
#  'PenaltyTeam',
#  'IsNoPlay',
#  'PenaltyType',
#  'PenaltyYards']

# %%
droplist = ["GameId","GameDate","Quarter","Minute","Second","Unnamed","SeriesFir"]
